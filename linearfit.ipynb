# %%
# %matplotlib inline
import numpy as np, scipy as sp, matplotlib.pyplot as plt
import random

no_of_points=50
Xpoints = np.linspace(-1.0,1.0,no_of_points)
Ystraight = Xpoints
Ypoints = np.linspace(0,0,no_of_points)

for i in range(no_of_points):
    Ypoints[i] = Ystraight[i]+random.uniform(-0.5, 0.5)
    
plt.plot(Xpoints, Ypoints, '.b')
plt.plot(Xpoints, Ystraight, '.g')
plt.suptitle('my plot')
plt.axis('equal')
plt.show()

# %%
def compute_error_for_line_given_points(b, m, points):
    totalError = 0
    for i in range(0, len(points)):
        x = points[i, 0]
        y = points[i, 1]
        totalError += (y - (m * x + b)) ** 2
    return totalError / float(len(points))

# %%
m = 1.1
n = 0.7
err1 = compute_error_for_given_points(m,n,Xpoints,Ypoints)
#len(Xpoints)    
Ytry = np.linspace(0,0,no_of_points)

for i in range(len(Xpoints)):
    x = Xpoints[i]
    y = Ypoints[i]
    Ytry[i] = (m * x + n)

plt.plot(Xpoints, Ytry, '.r')
plt.plot(Xpoints, Ypoints, '.b')        
plt.show()

# %%
def step_gradient(n_current, m_current, points, learningRate):
    n_gradient = 0
    m_gradient = 0
    N = float(len(points))
    for i in range(0, len(points)):
        x = points[i, 0]
        y = points[i, 1]
        n_gradient += -(2/N) * (y - ((m_current * x) + n_current))
        m_gradient += -(2/N) * x * (y - ((m_current * x) + n_current))
    new_n = b_current - (learningRate * b_gradient)
    new_m = m_current - (learningRate * m_gradient)
    return [new_n, new_m]

# %%
def gradient_descent_runner(points, starting_n, starting_m, learning_rate, num_iterations):
    n = starting_n
    m = starting_m
    for i in range(num_iterations):
        n, m = step_gradient(n, m, array(points), learning_rate)
    return [b, m]

# %%
points = [Xpoints , Ypoints]
learning_rate = 0.0001
initial_n = 0 # initial y-intercept guess
initial_m = 0 # initial slope guess
num_iterations = 1000
print "Starting gradient descent at n = {0}, m = {1}, error = {2}".format(initial_n, initial_m, compute_error_for_line_given_points(initial_n, initial_m, points))
print "Running..."
[n, m] = gradient_descent_runner(points, initial_n, initial_m, learning_rate, num_iterations)
print "After {0} iterations n = {1}, m = {2}, error = {3}".format(num_iterations, n, m, compute_error_for_line_given_points(n, m, points))
# Out:
#   Input In [57]
#     print "Starting gradient descent at n = {0}, m = {1}, error = {2}".format(initial_n, initial_m, compute_error_for_line_given_points(initial_n, initial_m, points))
#           ^
# SyntaxError: invalid syntax

# %%
import matplotlib.pyplot as plt
import numpy as np
from time import sleep

x = np.linspace(0, 10*np.pi, 100)
y = np.sin(x)
  
plt.ion()
fig = plt.figure()
ax = fig.add_subplot(111)
line1, = ax.plot(x, y, 'b-')
  
for phase in np.linspace(0, 10*np.pi, 100):
    line1.set_ydata(np.sin(0.5 * x + phase))
    fig.canvas.draw()
    fig.canvas.flush_events()

# %%
from IPython.display import clear_output
from matplotlib import pyplot as plt
import numpy as np
import collections
# %matplotlib inline

def live_plot(data_dict, figsize=(10,3), title=''):
    clear_output(wait=True)
    plt.figure(figsize=figsize)
    for label,data in data_dict.items():
        plt.plot(data, label=label)
    plt.title(title)
    plt.grid(True)
    plt.xlabel('epoch')
    plt.legend(loc='center left') # the plot evolves to the right
    plt.show();

# %%
data = collections.defaultdict(list)
for i in range(100):
    data['foo'].append(np.random.random())
    data['bar'].append(np.random.random())
    data['baz'].append(np.random.random())
    live_plot(data)
